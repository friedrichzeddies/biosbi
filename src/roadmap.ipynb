# %% [markdown]
# # Cryo-EM & SBI Interactive Roadmap
# Welcome! This notebook combines biophysics (cryo-EM) and simulation-based inference (SBI) for researchers of both domains. Use the interactive blocks to experiment and learn.
#
# ---

# %% [markdown]
# # Vision and roadmap
#
# ## Table of Contents / Checklist
#
# 1. Introduction    | []
#     - What is this project about    | []
#     - Why is this useful    | []
#         - biophys perspective    | []
#         - machine learning perspective    | []
#     - How to use this.    | []
#     - A starting challenge    | [] \
#     "Identify the object and the orientation" or similar to engage and introduce the specific problem.
# 2. Simulation pass     | []
#     - Biophysics theory    | []
#         - Tomography
#         - FT and aberrations
#         - sample prep
#         - ...
#     - Case study on a cat (display only?)    | []
#         - Projections    | []
#         - Errors: Aberrations (CTF), Signal to noise. Both individually displayed    | []
#     - Interactive block: Play around with the sim params, change object?    | [] \
#     **Might combine theory and case study to make it more understandable**
#     - Problem description: Why sbi might help (brief, teaser)     | []
# 3. Inference     | []
#     - SBI Theory recap     | []
#         - What is it (brief)
#     - connection to the problem (detailed)    | []
#         - inverse problem
#         - kind of parameters
#         - What do we actually learn and how
#         - ...
#     - Running some kind of inference?     | []
#         - displaying results of the authors?
#         - interactive?     | [] \
#         choose object freely (from pretrained models), special / edge cases?
#         - Technically, don't need to use only NFs right?
#     - Model Misspecification    | []
#         - interactive? choose kernels for mmd, use wrong test samples (trained on cat, use a dog), umap and other dimensionality reduction techniques
# 4. Summary     | []
#     - Concluding remarks on both Subjects     | []
#     - outlook?     | []
#     - Grand playground?     | [] \
#     choose from all models and some objects, run training yourself, ...
# 5. Credits / Sources / Acknowledgements

# %% [markdown]
# ## 1. Introduction
# Brief overview of the project and its purpose.
#
# - What is this project about?
# - Why is this useful?
#     - Biophysics perspective
#     - Machine learning perspective

# %%
# Placeholder for interactive FastAPI endpoint: Introduction
# (To be implemented)

# %% [markdown]
# ## 2. Simulation Pass
# Explore biophysics theory and run simulations. Includes interactive blocks for parameter manipulation.
#
# - Biophysics theory (Tomography, FT, aberrations, sample prep)
# - Case study: Cat projections and errors
# - Interactive: Change simulation parameters

# %%
# Placeholder for interactive FastAPI endpoint: Simulation parameters
# (To be implemented)

# %% [markdown]
# ## 3. Inference
# Learn about SBI theory and run inference tasks. Includes interactive blocks for experimenting with models and parameters.
#
# - SBI theory recap
# - Connection to biophysics problem (inverse problem, parameters, learning outcomes)
# - Run inference (display results, interactive selection of objects/models)
# - Model misspecification (interactive kernel selection, test samples, dimensionality reduction)

# %%
# Placeholder for interactive FastAPI endpoint: Inference experiments
# (To be implemented)

# %% [markdown]
# ## 4. Summary
# Concluding remarks and outlook. Optionally, a playground for further exploration.
#
# - Summary of biophysics and SBI
# - Outlook
# - Grand playground: Choose models/objects, run your own training

# %%
# Placeholder for interactive FastAPI endpoint: Playground
# (To be implemented)

# %% [markdown]
# ## 5. Credits / Sources / Acknowledgements
# List of references, contributors, and acknowledgements.
